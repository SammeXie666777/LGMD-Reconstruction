# %%
# %pip install neuron

from neuron.units import mV,ms,um # unit definition
from matplotlib import pyplot
import numpy as np
import itertools
from neuron import h, gui, rxd # chemical dynamic
import plotly
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from scipy.interpolate import interp1d
from scipy.optimize import differential_evolution
from neuron.units import mV, ms, um  # NEURON-defined units
# Out:
# Requirement already satisfied: neuron in /Users/samme/opt/anaconda3/lib/python3.9/site-packages (8.2.4)
# Requirement already satisfied: numpy>=1.9.3 in /Users/samme/opt/anaconda3/lib/python3.9/site-packages (from neuron) (1.24.3)
# Requirement already satisfied: packaging in /Users/samme/opt/anaconda3/lib/python3.9/site-packages (from neuron) (23.0)
# Requirement already satisfied: find-libpython in /Users/samme/opt/anaconda3/lib/python3.9/site-packages (from neuron) (0.3.1)
# Requirement already satisfied: setuptools in /Users/samme/opt/anaconda3/lib/python3.9/site-packages (from neuron) (67.8.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Loading 3D structure directly from swc file
h.load_file("stdlib.hoc")
h.load_file("import3d.hoc")


class LGMD:
    def __init__(self,morphology):
        self.morphology = morphology
        self.load_morphology()
        self.discretize()
    def __str__(self):
        return self.morphology
    def discretize(self):
        for sec in self.all:
            sec.nseg = int(sec.L) +1
            if sec.nseg % 2 == 0:
                sec.nseg += 1
    def load_morphology(self):
        # Create a cell object
        LGMD = h.Import3d_SWC_read()
        LGMD.input(f"{self.morphology}.swc")
        i3d = h.Import3d_GUI(LGMD, False)
        i3d.instantiate(self)
        #self.set_nseg_by_d_lambda(d_lambda=0.1)  # You can adjust d_lambda as needed

# Instantiate the LGMD class
LGMD1 = LGMD ("/Users/samme/Library/CloudStorage/OneDrive-Emory/Lab/LGMD project/LGMD_Data/LGMD_Reconstruction/Output/Fully_Connected_LGMD_sorted.hoc")

# Plot the shape of the cell
ps = h.PlotShape(False)
ps.plot(plotly).show()
# Out:
# NEURON: /Users/samme/Library/CloudStorage/OneDrive-Emory/Lab/LGMD project/LGMD_Data/LGMD_Reconstruction/Output/Fully_Connected_LGMD_sorted.swc :file is not open
#  near line 0
#  ^
#         File[0].eof()
#       Import3d_SWC_read[0].rdfile("/Users/sam...")
#     Import3d_SWC_read[0].input("/Users/sam...")
# could not open /Users/samme/Library/CloudStorage/OneDrive-Emory/Lab/LGMD project/LGMD_Data/LGMD_Reconstruction/Output/Fully_Connected_LGMD_sorted.swc
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/b_/nsxy2w2j4l50cg4c0jxc0qyr0000gn/T/ipykernel_31684/2543307558.py in <module>
#      25
#      26 # Instantiate the LGMD class
# ---> 27 LGMD1 = LGMD ("/Users/samme/Library/CloudStorage/OneDrive-Emory/Lab/LGMD project/LGMD_Data/LGMD_Reconstruction/Output/Fully_Connected_LGMD_sorted")
#      28
#      29 # Plot the shape of the cell
#
# /var/folders/b_/nsxy2w2j4l50cg4c0jxc0qyr0000gn/T/ipykernel_31684/2543307558.py in __init__(self, morphology)
#       7     def __init__(self,morphology):
#       8         self.morphology = morphology
# ----> 9         self.load_morphology()
#      10         self.discretize()
#      11     def __str__(self):
#
# /var/folders/b_/nsxy2w2j4l50cg4c0jxc0qyr0000gn/T/ipykernel_31684/2543307558.py in load_morphology(self)
#      19         # Create a cell object
#      20         LGMD = h.Import3d_SWC_read()
# ---> 21         LGMD.input(f"{self.morphology}.swc")
#      22         i3d = h.Import3d_GUI(LGMD, False)
#      23         i3d.instantiate(self)
#
# RuntimeError: hocobj_call error

# %%
# Load hoc file directly
h.load_file("stdlib.hoc")
h.load_file("import3d.hoc")
def load_neuron_model(hoc_file_path):
    """
    Load a neuron model from a hoc file, set up the NEURON environment,
    and allow for flexible naming of the NEURON object.

    """
    # Import NEURON module and load the hoc file
    h.load_file(hoc_file_path)

    # Create a PlotShape object for visualization
    ps = h.PlotShape(False)
    ps.plot(plotly).show()

    neuron_obj = h
    return neuron_obj

hocpath = "/Users/samme/Library/CloudStorage/OneDrive-Emory/Lab/LGMD_project/code/Python_Neuron/LGMD_Complete_Construction.hoc"
LGMD1 = load_neuron_model(hocpath)

# %%
# get information for all segments
import itertools

def neuron_info(neuron_obj):
    """
    Prints information about the neuron model loaded in NEURON, such as the
    number of sections, minimum and maximum diameters, and details for each section.

    Parameters:
        neuron_obj: The NEURON object containing the model.
    """
    # Calculate the number of sections
    num_sections = sum(1 for _ in neuron_obj.allsec())
    print(f"Number of sections: {num_sections}")

    # Flatten diameters of all sections into a single list
    all_dims = list(itertools.chain.from_iterable(
        [[sec.diam3d(i) for i in range(sec.n3d())] for sec in neuron_obj.allsec()]
    ))

    print(f"Minimum diameter = {min(all_dims)} um")
    print(f"Maximum diameter = {max(all_dims)} um")

    # Print detailed information for each section
    for sec in neuron_obj.allsec():
        print(f"Section name: {sec.name()}")
        print(f"  Number of segments (nseg): {sec.nseg}")
        print(f"  Number of nodes: {int(sec.n3d())}")
        print(f"  Length (um): {sec.L}")
        print(f"  Diameter (um): {sec.diam}")

neuron_info(LGMD1)  # call
# Out:
# Number of sections: 2896
# Minimum diameter = 2.0 um
# Maximum diameter = 36.0 um
# Section name: soma[0]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 6.4602002867936825
#   Diameter (um): 8.399999618530273
# Section name: Axon[0]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.826938688092878
#   Diameter (um): 8.699999809265137
# Section name: Axon[1]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.424857108840021
#   Diameter (um): 9.0
# Section name: Axon[2]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.8043933921246964
#   Diameter (um): 8.999999999999998
# Section name: Axon[3]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.435601148968551
#   Diameter (um): 9.500000000000002
# Section name: Axon[4]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.1545915260185815
#   Diameter (um): 10.0
# Section name: Axon[5]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.905688794045998
#   Diameter (um): 10.599999904632568
# Section name: Axon[6]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.944410635182425
#   Diameter (um): 11.199999809265137
# Section name: Axon[7]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 7.100344775799054
#   Diameter (um): 11.599999904632568
# Section name: Axon[8]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.0088668778627135
#   Diameter (um): 12.0
# Section name: Axon[9]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 8.145543576937678
#   Diameter (um): 13.5
# Section name: Axon[10]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.317021070883471
#   Diameter (um): 15.0
# Section name: Axon[11]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 7.680020185308883
#   Diameter (um): 16.0
# Section name: Axon[12]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.686924440319341
#   Diameter (um): 16.999999999999996
# Section name: Axon[13]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.862766877921312
#   Diameter (um): 17.0
# Section name: Axon[14]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.840026033685313
#   Diameter (um): 16.5
# Section name: Axon[15]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.131883473191606
#   Diameter (um): 16.0
# Section name: Axon[16]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.702452203540094
#   Diameter (um): 16.0
# Section name: Axon[17]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 8.71178461199567
#   Diameter (um): 18.0
# Section name: Axon[18]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.916292625484513
#   Diameter (um): 20.0
# Section name: Axon[19]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 8.62909610475967
#   Diameter (um): 21.399999618530273
# Section name: Axon[20]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.817587574174734
#   Diameter (um): 22.799999237060543
# Section name: Axon[21]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 9.247037357461851
#   Diameter (um): 21.399999618530273
# Section name: Axon[22]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.850425772675144
#   Diameter (um): 20.0
# Section name: Axon[23]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 9.87752835389022
#   Diameter (um): 21.500000000000004
# Section name: Axon[24]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.716233863099324
#   Diameter (um): 23.0
# Section name: Axon[25]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 10.242488263724534
#   Diameter (um): 23.5
# Section name: Axon[26]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.2673289087697635
#   Diameter (um): 24.0
# Section name: Axon[27]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 8.175809771399294
#   Diameter (um): 22.999999999999996
# Section name: Axon[28]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.6870944746754875
#   Diameter (um): 22.0
# Section name: Axon[29]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 9.332619893667985
#   Diameter (um): 24.800000190734863
# Section name: Axon[30]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.191195880831351
#   Diameter (um): 27.600000381469727
# Section name: Axon[31]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 10.548267295849087
#   Diameter (um): 27.900000572204586
# Section name: Axon[32]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 7.078488905702022
#   Diameter (um): 28.200000762939453
# Section name: Axon[33]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 7.50411410111503
#   Diameter (um): 22.100000381469727
# Section name: Axon[34]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 7.2248810501670935
#   Diameter (um): 19.5
# Section name: Axon[35]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.598297328959888
#   Diameter (um): 23.0
# Section name: Axon[36]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 12.84316880623227
#   Diameter (um): 25.899999618530277
# Section name: Axon[37]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.1575186806973377
#   Diameter (um): 28.799999237060547
# Section name: Axon[38]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 13.67659426095624
#   Diameter (um): 29.399999618530273
# Section name: Axon[39]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.9018101041983915
#   Diameter (um): 30.0
# Section name: Axon[40]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 16.13632674156328
#   Diameter (um): 31.600000381469723
# Section name: Axon[41]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.788956406425462
#   Diameter (um): 33.20000076293945
# Section name: Axon[42]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 14.278091380072071
#   Diameter (um): 29.10000038146973
# Section name: Axon[43]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.5584581495648546
#   Diameter (um): 25.0
# Section name: FieldA[0]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 11.83370288569223
#   Diameter (um): 21.5
# Section name: FieldA[1]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 8.80706292340661
#   Diameter (um): 19.0
# Section name: FieldA[2]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 12.253208656845267
#   Diameter (um): 22.000000000000004
# Section name: FieldA[3]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.537045781734984
#   Diameter (um): 23.999999999999996
# Section name: FieldA[4]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.897011933728818
#   Diameter (um): 24.0
# Section name: FieldA[5]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 10.478068021953714
#   Diameter (um): 26.199999809265137
# Section name: FieldA[6]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.658497030180196
#   Diameter (um): 28.399999618530273
# Section name: FieldA[7]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.478513617991183
#   Diameter (um): 28.399999618530277
# Section name: FieldA[8]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 8.27803298806626
#   Diameter (um): 28.699999809265137
# Section name: FieldA[9]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.869114522470934
#   Diameter (um): 29.0
# Section name: FieldA[10]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.718888911416025
#   Diameter (um): 29.000000000000004
# Section name: FieldA[11]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 8.052125431402043
#   Diameter (um): 30.0
# Section name: FieldA[12]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.731291636017406
#   Diameter (um): 31.000000000000004
# Section name: FieldA[13]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.888455449339952
#   Diameter (um): 31.0
# Section name: FieldA[14]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 10.174532041252311
#   Diameter (um): 27.69999980926514
# Section name: FieldA[15]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.211912510701721
#   Diameter (um): 24.399999618530273
# Section name: FieldA[16]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.165429017383013
#   Diameter (um): 24.399999618530273
# Section name: FieldA[17]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 8.821573585397978
#   Diameter (um): 22.199999809265137
# Section name: FieldA[18]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.598045930603272
#   Diameter (um): 19.999999999999996
# Section name: FieldA[19]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 12.635774593304715
#   Diameter (um): 21.699999809265137
# Section name: FieldA[20]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.392795448918882
#   Diameter (um): 23.399999618530273
# Section name: FieldA[21]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 9.114056353011684
#   Diameter (um): 17.699999809265137
# Section name: FieldA[22]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.13377611051572
#   Diameter (um): 12.0
# Section name: FieldA[23]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.71472364878068
#   Diameter (um): 14.000000000000002
# Section name: FieldA[24]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.3992556507717335
#   Diameter (um): 16.0
# Section name: FieldA[25]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 6.3969617594142845
#   Diameter (um): 15.699999809265138
# Section name: FieldA[26]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.566677821540176
#   Diameter (um): 15.399999618530273
# Section name: FieldA[27]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 6.771553545140702
#   Diameter (um): 15.399999618530275
# Section name: FieldA[28]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.193491889939051
#   Diameter (um): 15.399999618530272
# Section name: FieldA[29]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.3702675562567554
#   Diameter (um): 14.399999618530273
# Section name: FieldA[30]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.065009807664135
#   Diameter (um): 13.399999618530273
# Section name: FieldA[31]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.4150033588851456
#   Diameter (um): 13.399999618530273
# Section name: FieldA[32]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.35726758797053
#   Diameter (um): 14.299999713897707
# Section name: FieldA[33]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.924957883218644
#   Diameter (um): 15.199999809265138
# Section name: FieldA[34]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.661281769109558
#   Diameter (um): 15.199999809265138
# Section name: FieldA[35]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.033961349844786
#   Diameter (um): 15.099999904632568
# Section name: FieldA[36]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.6472666500044046
#   Diameter (um): 15.0
# Section name: FieldA[37]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.0389042877634647
#   Diameter (um): 16.0
# Section name: FieldA[38]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.809183395083748
#   Diameter (um): 17.0
# Section name: FieldA[39]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 6.922798043544075
#   Diameter (um): 16.5
# Section name: FieldA[40]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.716380263054638
#   Diameter (um): 16.0
# Section name: FieldA[41]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.840591339058322
#   Diameter (um): 15.0
# Section name: FieldA[42]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.752939876297633
#   Diameter (um): 14.000000000000002
# Section name: FieldA[43]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.991240014193628
#   Diameter (um): 11.999999999999998
# Section name: FieldA[44]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.8877275465462855
#   Diameter (um): 9.0
# Section name: FieldA[45]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.7806099296150455
#   Diameter (um): 7.500000000000001
# Section name: FieldA[46]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 7.493256757007006
#   Diameter (um): 7.000000000000001
# Section name: FieldA[47]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.277595560536057
#   Diameter (um): 6.5
# Section name: FieldA[48]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.169813701049561
#   Diameter (um): 5.000000000000001
# Section name: FieldA[49]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.463840400984506
#   Diameter (um): 5.0
# Section name: FieldA[50]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.038878037685639
#   Diameter (um): 5.0
# Section name: FieldA[51]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.184545859644221
#   Diameter (um): 4.0
# Section name: FieldA[52]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.8908230998803988
#   Diameter (um): 5.0
# Section name: FieldA[53]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.8504042682295707
#   Diameter (um): 6.0
# Section name: FieldA[54]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.092838309452466
#   Diameter (um): 5.000000000000001
# Section name: FieldA[55]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.3573273658178326
#   Diameter (um): 3.2999999523162837
# Section name: FieldA[56]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.182164409200597
#   Diameter (um): 2.5999999046325684
# Section name: FieldA[57]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 0.9527818542611286
#   Diameter (um): 2.299999952316284
# Section name: FieldA[58]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.5261484789787927
#   Diameter (um): 2.0
# Section name: FieldA[59]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.509774959167833
#   Diameter (um): 5.0
# Section name: FieldA[60]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.717586687899042
#   Diameter (um): 5.0
# Section name: FieldA[61]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.2025675239436504
#   Diameter (um): 5.0
# Section name: FieldA[62]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.998313209883927
#   Diameter (um): 3.335000038146972
# Section name: FieldA[63]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 8.601821372272607
#   Diameter (um): 2.3350000381469727
# Section name: FieldA[64]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.0363967308805444
#   Diameter (um): 2.0
# Section name: FieldA[65]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 6.224511545653299
#   Diameter (um): 2.0
# Section name: FieldA[66]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.203758613028139
#   Diameter (um): 1.9999999999999998
# Section name: FieldA[67]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 7.461383202512876
#   Diameter (um): 15.499999999999998
# Section name: FieldA[68]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.9022546614884575
#   Diameter (um): 19.0
# Section name: FieldA[69]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.7883231189142927
#   Diameter (um): 18.300000190734863
# Section name: FieldA[70]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.952603396321784
#   Diameter (um): 17.600000381469727
# Section name: FieldA[71]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 8.343283460746353
#   Diameter (um): 13.100000381469727
# Section name: FieldA[72]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.390689683422661
#   Diameter (um): 8.600000381469727
# Section name: FieldA[73]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.452709531558371
#   Diameter (um): 8.700000286102295
# Section name: FieldA[74]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.6780162224734263
#   Diameter (um): 8.800000190734863
# Section name: FieldA[75]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.982632526479524
#   Diameter (um): 9.400000095367432
# Section name: FieldA[76]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.8414307233697746
#   Diameter (um): 10.0
# Section name: FieldA[77]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.173232760525146
#   Diameter (um): 10.40000009536743
# Section name: FieldA[78]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 26.30425311306611
#   Diameter (um): 20.800000190734863
# Section name: FieldA[79]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.926364203973632
#   Diameter (um): 12.600000381469727
# Section name: FieldA[80]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.7332407619091885
#   Diameter (um): 13.100000381469728
# Section name: FieldA[81]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.0478861857265755
#   Diameter (um): 13.600000381469727
# Section name: FieldA[82]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.560204510070292
#   Diameter (um): 13.600000381469727
# Section name: FieldA[83]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 6.3505643905722575
#   Diameter (um): 16.5
# Section name: FieldA[84]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.257707194816419
#   Diameter (um): 19.399999618530273
# Section name: FieldA[85]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.982377209034059
#   Diameter (um): 19.39999961853027
# Section name: FieldA[86]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 8.609011041112888
#   Diameter (um): 20.0
# Section name: FieldA[87]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.561167796057268
#   Diameter (um): 20.600000381469727
# Section name: FieldA[88]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 10.20484574469732
#   Diameter (um): 21.800000190734863
# Section name: FieldA[89]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.418726374362809
#   Diameter (um): 23.000000000000004
# Section name: FieldA[90]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 11.405746178949371
#   Diameter (um): 15.500000000000002
# Section name: FieldA[91]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.873658686089946
#   Diameter (um): 8.0
# Section name: FieldA[92]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.210297726596355
#   Diameter (um): 7.0
# Section name: FieldA[93]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.540736596984461
#   Diameter (um): 6.0
# Section name: FieldA[94]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.5182365126851356
#   Diameter (um): 6.0
# Section name: FieldA[95]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.765429163498949
#   Diameter (um): 5.0
# Section name: FieldA[96]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.8672243393596704
#   Diameter (um): 4.299999952316284
# Section name: FieldA[97]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.055774697717487
#   Diameter (um): 4.5999999046325675
# Section name: FieldA[98]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.31250260340753
#   Diameter (um): 4.599999904632568
# Section name: FieldA[99]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.5144739287318085
#   Diameter (um): 4.299999952316283
# Section name: FieldA[100]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.754376842214991
#   Diameter (um): 4.0
# Section name: FieldA[101]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.7826696713788928
#   Diameter (um): 3.499999999999999
# Section name: FieldA[102]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.5287316574131955
#   Diameter (um): 3.0
# Section name: FieldA[103]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.810569490755944
#   Diameter (um): 4.399999976158142
# Section name: FieldA[104]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 6.336289233855651
#   Diameter (um): 2.799999952316284
# Section name: FieldA[105]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 7.441009364423237
#   Diameter (um): 21.5
# Section name: FieldA[106]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.400186595819642
#   Diameter (um): 19.999999999999996
# Section name: FieldA[107]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 9.41853622500579
#   Diameter (um): 19.5
# Section name: FieldA[108]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.781617239079483
#   Diameter (um): 19.000000000000004
# Section name: FieldA[109]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 7.440087187885919
#   Diameter (um): 16.0
# Section name: FieldA[110]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.4009577185774678
#   Diameter (um): 13.0
# Section name: FieldA[111]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 6.7668246148883915
#   Diameter (um): 10.5
# Section name: FieldA[112]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 9.681963780984411
#   Diameter (um): 14.000000000000002
# Section name: FieldA[113]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.164774617610755
#   Diameter (um): 9.0
# Section name: FieldA[114]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.126500616274078
#   Diameter (um): 9.0
# Section name: FieldA[115]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.406324838044693
#   Diameter (um): 9.0
# Section name: FieldA[116]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.885225097735937
#   Diameter (um): 8.299999952316286
# Section name: FieldA[117]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.934660705229999
#   Diameter (um): 7.599999904632569
# Section name: FieldA[118]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.9074439038242694
#   Diameter (um): 7.5
# Section name: FieldA[119]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.0160808608665475
#   Diameter (um): 7.400000095367432
# Section name: FieldA[120]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.8162918243573234
#   Diameter (um): 7.400000095367432
# Section name: FieldA[121]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.832190225071043
#   Diameter (um): 8.200000047683716
# Section name: FieldA[122]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.488198763738725
#   Diameter (um): 9.0
# Section name: FieldA[123]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.0841308099345506
#   Diameter (um): 7.700000047683716
# Section name: FieldA[124]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.009435051678202
#   Diameter (um): 6.400000095367432
# Section name: FieldA[125]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.542731648655606
#   Diameter (um): 7.200000047683717
# Section name: FieldA[126]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.8394763192108874
#   Diameter (um): 8.0
# Section name: FieldA[127]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.686547187229732
#   Diameter (um): 7.999999999999999
# Section name: FieldA[128]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.8961708514420004
#   Diameter (um): 8.300000190734862
# Section name: FieldA[129]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.8843992058011945
#   Diameter (um): 8.600000381469725
# Section name: FieldA[130]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.0027670304122647
#   Diameter (um): 9.300000190734863
# Section name: FieldA[131]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.9892505379908734
#   Diameter (um): 9.0
# Section name: FieldA[132]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.471513332417528
#   Diameter (um): 6.999999999999999
# Section name: FieldA[133]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.7385400095103702
#   Diameter (um): 6.0
# Section name: FieldA[134]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.285258280615275
#   Diameter (um): 5.0
# Section name: FieldA[135]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.5531634138421078
#   Diameter (um): 4.5
# Section name: FieldA[136]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.760651065956955
#   Diameter (um): 5.0
# Section name: FieldA[137]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.6679853117034595
#   Diameter (um): 4.5
# Section name: FieldA[138]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.6822768000033808
#   Diameter (um): 4.0
# Section name: FieldA[139]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.194986212873583
#   Diameter (um): 4.0
# Section name: FieldA[140]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.9463070782270493
#   Diameter (um): 4.0
# Section name: FieldA[141]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.416890196331167
#   Diameter (um): 4.0
# Section name: FieldA[142]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.3651446404450605
#   Diameter (um): 8.0
# Section name: FieldA[143]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.0869500297054864
#   Diameter (um): 9.0
# Section name: FieldA[144]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.525537772076117
#   Diameter (um): 10.0
# Section name: FieldA[145]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.2678792309418205
#   Diameter (um): 10.300000190734863
# Section name: FieldA[146]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.698620864799546
#   Diameter (um): 10.600000381469728
# Section name: FieldA[147]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.8605492528286574
#   Diameter (um): 10.200000286102293
# Section name: FieldA[148]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.180688691439813
#   Diameter (um): 9.800000190734863
# Section name: FieldA[149]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.492513951123624
#   Diameter (um): 9.400000095367432
# Section name: FieldA[150]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.673332222492395
#   Diameter (um): 9.0
# Section name: FieldA[151]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.065931268697538
#   Diameter (um): 9.0
# Section name: FieldA[152]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.9681760184616075
#   Diameter (um): 8.09999990463257
# Section name: FieldA[153]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.205341491267712
#   Diameter (um): 7.199999809265137
# Section name: FieldA[154]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.2526616561110764
#   Diameter (um): 7.5999999046325675
# Section name: FieldA[155]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.702006097456894
#   Diameter (um): 6.999999999999999
# Section name: FieldA[156]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.4729540512529926
#   Diameter (um): 5.0
# Section name: FieldA[157]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.524930253488995
#   Diameter (um): 3.0
# Section name: FieldA[158]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 7.73246150732001
#   Diameter (um): 9.300000190734863
# Section name: FieldA[159]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.8020793871635923
#   Diameter (um): 6.0
# Section name: FieldA[160]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.555968679708758
#   Diameter (um): 5.999999999999999
# Section name: FieldA[161]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.20556501353036
#   Diameter (um): 5.5
# Section name: FieldA[162]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.418072054787841
#   Diameter (um): 5.000000000000001
# Section name: FieldA[163]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.0316545667549437
#   Diameter (um): 5.200000047683716
# Section name: FieldA[164]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.22334220557552
#   Diameter (um): 5.400000095367432
# Section name: FieldA[165]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.367717295151387
#   Diameter (um): 5.400000095367432
# Section name: FieldA[166]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 0.6314965485208575
#   Diameter (um): 3.700000047683716
# Section name: FieldA[167]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.903875441348651
#   Diameter (um): 2.664999961853027
# Section name: FieldA[168]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.6567721482151545
#   Diameter (um): 3.664999961853027
# Section name: FieldA[169]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.6817507822672935
#   Diameter (um): 4.0
# Section name: FieldA[170]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.507292739768364
#   Diameter (um): 3.0000000000000004
# Section name: FieldA[171]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 6.1439770709262085
#   Diameter (um): 12.800000190734863
# Section name: FieldA[172]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.564962120359103
#   Diameter (um): 12.600000381469727
# Section name: FieldA[173]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.19078004947336
#   Diameter (um): 13.800000190734863
# Section name: FieldA[174]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.57732998812017
#   Diameter (um): 15.0
# Section name: FieldA[175]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.48496511346679
#   Diameter (um): 15.0
# Section name: FieldA[176]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.395641281343088
#   Diameter (um): 11.900000095367432
# Section name: FieldA[177]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 6.134186899646202
#   Diameter (um): 8.400000095367432
# Section name: FieldA[178]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.348037011610801
#   Diameter (um): 7.0
# Section name: FieldA[179]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.4882472255857757
#   Diameter (um): 6.999999999999999
# Section name: FieldA[180]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.598700828957605
#   Diameter (um): 8.0
# Section name: FieldA[181]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.4002728726753118
#   Diameter (um): 7.299999952316283
# Section name: FieldA[182]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.30371949188736
#   Diameter (um): 6.599999904632568
# Section name: FieldA[183]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.58577041501137
#   Diameter (um): 6.599999904632569
# Section name: FieldA[184]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.9551208552874717
#   Diameter (um): 7.099999904632569
# Section name: FieldA[185]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.0661085494614673
#   Diameter (um): 7.5999999046325675
# Section name: FieldA[186]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.3929037543565217
#   Diameter (um): 7.599999904632569
# Section name: FieldA[187]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.3945384997072603
#   Diameter (um): 7.5999999046325675
# Section name: FieldA[188]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.9319812563785574
#   Diameter (um): 8.100000143051147
# Section name: FieldA[189]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.3574224821854224
#   Diameter (um): 8.600000381469727
# Section name: FieldA[190]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.5804493474143286
#   Diameter (um): 8.600000381469727
# Section name: FieldA[191]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.7238977091293393
#   Diameter (um): 8.800000190734863
# Section name: FieldA[192]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.1071204550151257
#   Diameter (um): 9.0
# Section name: FieldA[193]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.6815880558260172
#   Diameter (um): 9.0
# Section name: FieldA[194]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.7830472423689363
#   Diameter (um): 9.5
# Section name: FieldA[195]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.341564565171968
#   Diameter (um): 9.0
# Section name: FieldA[196]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.6883151542299224
#   Diameter (um): 7.0
# Section name: FieldA[197]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.167456603396864
#   Diameter (um): 6.0
# Section name: FieldA[198]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.53128116258343
#   Diameter (um): 7.0
# Section name: FieldA[199]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.912829834907031
#   Diameter (um): 6.0
# Section name: FieldA[200]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.825569603690848
#   Diameter (um): 4.0
# Section name: FieldA[201]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.29454108797275
#   Diameter (um): 5.0
# Section name: FieldA[202]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.0055941251157257
#   Diameter (um): 5.0
# Section name: FieldA[203]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.566387395721945
#   Diameter (um): 4.0
# Section name: FieldA[204]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.355775208103094
#   Diameter (um): 4.0
# Section name: FieldA[205]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.859261664899973
#   Diameter (um): 4.0
# Section name: FieldA[206]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.836812289946528
#   Diameter (um): 4.0
# Section name: FieldA[207]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.849518756711409
#   Diameter (um): 4.0
# Section name: FieldA[208]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.352988591799899
#   Diameter (um): 4.0
# Section name: FieldA[209]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.6891160176781652
#   Diameter (um): 4.0
# Section name: FieldA[210]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.459081555574337
#   Diameter (um): 3.0
# Section name: FieldA[211]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.901481735138098
#   Diameter (um): 8.300000190734863
# Section name: FieldA[212]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.491669535370354
#   Diameter (um): 8.999999999999998
# Section name: FieldA[213]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.6653654349985594
#   Diameter (um): 7.999999999999999
# Section name: FieldA[214]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.99669555894308
#   Diameter (um): 5.999999999999999
# Section name: FieldA[215]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.6074197109263437
#   Diameter (um): 6.0
# Section name: FieldA[216]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.088073647665288
#   Diameter (um): 6.0
# Section name: FieldA[217]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.042145520076382
#   Diameter (um): 5.000000000000001
# Section name: FieldA[218]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.50241369798151
#   Diameter (um): 5.0
# Section name: FieldA[219]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.894162918334043
#   Diameter (um): 6.0
# Section name: FieldA[220]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.189827569959514
#   Diameter (um): 6.0
# Section name: FieldA[221]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.0666056921682663
#   Diameter (um): 4.999999999999999
# Section name: FieldA[222]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.5007778188541487
#   Diameter (um): 4.0
# Section name: FieldA[223]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.7037231192635167
#   Diameter (um): 4.0
# Section name: FieldA[224]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.7669388697616846
#   Diameter (um): 4.335000038146973
# Section name: FieldA[225]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.283060809737824
#   Diameter (um): 5.335000038146973
# Section name: FieldA[226]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.1986669377018733
#   Diameter (um): 8.800000190734863
# Section name: FieldA[227]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.9001238759300416
#   Diameter (um): 8.800000190734863
# Section name: FieldA[228]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.047057522600863
#   Diameter (um): 8.400000095367432
# Section name: FieldA[229]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.640410673455431
#   Diameter (um): 8.0
# Section name: FieldA[230]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.555306245509003
#   Diameter (um): 8.0
# Section name: FieldA[231]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.9728400069872594
#   Diameter (um): 7.499999999999999
# Section name: FieldA[232]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.593684345564328
#   Diameter (um): 7.0
# Section name: FieldA[233]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.78030077950466
#   Diameter (um): 7.099999904632568
# Section name: FieldA[234]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.7369793073260107
#   Diameter (um): 7.199999809265136
# Section name: FieldA[235]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.752695380409545
#   Diameter (um): 7.199999809265136
# Section name: FieldA[236]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.619391876908468
#   Diameter (um): 7.599999904632568
# Section name: FieldA[237]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.031503277534199
#   Diameter (um): 7.0
# Section name: FieldA[238]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.079770885717754
#   Diameter (um): 6.0
# Section name: FieldA[239]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.3565494875604625
#   Diameter (um): 6.0
# Section name: FieldA[240]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.8872988570704154
#   Diameter (um): 5.999999999999999
# Section name: FieldA[241]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.35151650278832
#   Diameter (um): 5.0
# Section name: FieldA[242]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.4948652471444477
#   Diameter (um): 3.9999999999999996
# Section name: FieldA[243]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.38412343642571
#   Diameter (um): 5.000000000000001
# Section name: FieldA[244]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.4704046744808195
#   Diameter (um): 5.0
# Section name: FieldA[245]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.2028176743618735
#   Diameter (um): 4.0
# Section name: FieldA[246]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.001958872466105
#   Diameter (um): 10.800000190734862
# Section name: FieldA[247]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.9569490576745108
#   Diameter (um): 9.400000095367432
# Section name: FieldA[248]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.7150900730074756
#   Diameter (um): 8.0
# Section name: FieldA[249]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.523401805247042
#   Diameter (um): 8.0
# Section name: FieldA[250]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.441896405845751
#   Diameter (um): 7.999999999999999
# Section name: FieldA[251]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.7142435766958175
#   Diameter (um): 8.0
# Section name: FieldA[252]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 0.7156095880900911
#   Diameter (um): 7.299999952316283
# Section name: FieldA[253]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.388486414796905
#   Diameter (um): 6.599999904632568
# Section name: FieldA[254]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 0.8552781965426487
#   Diameter (um): 6.299999952316285
# Section name: FieldA[255]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.280383064420453
#   Diameter (um): 6.0
# Section name: FieldA[256]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.3765964188061142
#   Diameter (um): 6.0
# Section name: FieldA[257]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.333405395148127
#   Diameter (um): 6.0
# Section name: FieldA[258]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.8804563394374987
#   Diameter (um): 6.0
# Section name: FieldA[259]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.6058349871807611
#   Diameter (um): 5.700000047683717
# Section name: FieldA[260]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.476587156360814
#   Diameter (um): 5.400000095367432
# Section name: FieldA[261]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.818617896823533
#   Diameter (um): 5.400000095367432
# Section name: FieldA[262]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 8.499413838367795
#   Diameter (um): 17.800000190734863
# Section name: FieldA[263]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.3034259615866364
#   Diameter (um): 18.0
# Section name: FieldA[264]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 7.195032656931397
#   Diameter (um): 16.999999999999996
# Section name: FieldA[265]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.1733061859516045
#   Diameter (um): 16.0
# Section name: FieldA[266]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.756772647214978
#   Diameter (um): 16.0
# Section name: FieldA[267]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.1801216144314015
#   Diameter (um): 16.0
# Section name: FieldA[268]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.929304604185353
#   Diameter (um): 16.0
# Section name: FieldA[269]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.108459234354548
#   Diameter (um): 16.0
# Section name: FieldA[270]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.4045872805513286
#   Diameter (um): 16.0
# Section name: FieldA[271]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.873670796116885
#   Diameter (um): 14.300000190734863
# Section name: FieldA[272]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.7625754070829585
#   Diameter (um): 12.600000381469725
# Section name: FieldA[273]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.255327525762077
#   Diameter (um): 12.600000381469725
# Section name: FieldA[274]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 6.2031142799564964
#   Diameter (um): 10.300000190734863
# Section name: FieldA[275]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.34908875211068
#   Diameter (um): 8.0
# Section name: FieldA[276]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.619108730498172
#   Diameter (um): 8.199999809265137
# Section name: FieldA[277]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.557541973758487
#   Diameter (um): 8.399999618530273
# Section name: FieldA[278]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.8796614934065077
#   Diameter (um): 8.399999618530273
# Section name: FieldA[279]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.8809914787020428
#   Diameter (um): 8.199999809265137
# Section name: FieldA[280]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.520348748364869
#   Diameter (um): 8.0
# Section name: FieldA[281]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.499803789147886
#   Diameter (um): 8.0
# Section name: FieldA[282]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.1208036720642442
#   Diameter (um): 8.0
# Section name: FieldA[283]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.0768946998075433
#   Diameter (um): 8.0
# Section name: FieldA[284]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.834196011032146
#   Diameter (um): 8.5
# Section name: FieldA[285]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.6549487635394975
#   Diameter (um): 8.999999999999998
# Section name: FieldA[286]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.564224536339748
#   Diameter (um): 9.000000000000002
# Section name: FieldA[287]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.500558030185112
#   Diameter (um): 9.0
# Section name: FieldA[288]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.301552350558694
#   Diameter (um): 9.0
# Section name: FieldA[289]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.832293526655777
#   Diameter (um): 7.499999999999999
# Section name: FieldA[290]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.020018416310819
#   Diameter (um): 6.0
# Section name: FieldA[291]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.6262810002357644
#   Diameter (um): 6.000000000000001
# Section name: FieldA[292]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.312184044989875
#   Diameter (um): 6.0
# Section name: FieldA[293]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.243283628721002
#   Diameter (um): 6.0
# Section name: FieldA[294]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.256125264929236
#   Diameter (um): 5.0
# Section name: FieldA[295]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.682864236355939
#   Diameter (um): 11.300000190734863
# Section name: FieldA[296]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.1296022030728
#   Diameter (um): 9.0
# Section name: FieldA[297]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.7251651267136305
#   Diameter (um): 8.0
# Section name: FieldA[298]
#   Number of segments (nseg): 1
# ...
# Section name: Cellbody[38]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.969377435571725
#   Diameter (um): 8.0
# Section name: Cellbody[39]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.4428387048264204
#   Diameter (um): 9.0
# Section name: Cellbody[40]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.37244122205023
#   Diameter (um): 10.000000000000002
# Section name: Cellbody[41]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.5313324576317804
#   Diameter (um): 9.59999990463257
# Section name: Cellbody[42]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.182276340503573
#   Diameter (um): 9.199999809265137
# Section name: Cellbody[43]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.5075588547049525
#   Diameter (um): 9.199999809265137
# Section name: Cellbody[44]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.2694197644515894
#   Diameter (um): 8.599999904632568
# Section name: Cellbody[45]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.16291477500741
#   Diameter (um): 8.0
# Section name: Cellbody[46]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.2657361450579385
#   Diameter (um): 8.0
# Section name: Cellbody[47]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.731405899256955
#   Diameter (um): 7.299999952316285
# Section name: Cellbody[48]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.096170227659736
#   Diameter (um): 6.599999904632568
# Section name: Cellbody[49]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.638426487893212
#   Diameter (um): 6.599999904632568
# Section name: Cellbody[50]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.1073927283174045
#   Diameter (um): 7.299999952316284
# Section name: Cellbody[51]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.687119682500013
#   Diameter (um): 8.0
# Section name: Cellbody[52]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.408846799471714
#   Diameter (um): 6.999999999999999
# Section name: Cellbody[53]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.3817312306065688
#   Diameter (um): 6.0
# Section name: Cellbody[54]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.642896938989709
#   Diameter (um): 6.0
# Section name: Cellbody[55]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.9685015762573523
#   Diameter (um): 5.999999999999999
# Section name: Cellbody[56]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.4771093886771105
#   Diameter (um): 6.0
# Section name: Cellbody[57]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.6704965340041236
#   Diameter (um): 5.0
# Section name: Cellbody[58]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.08645494519922
#   Diameter (um): 5.0
# Section name: Cellbody[59]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.671218058804994
#   Diameter (um): 6.0
# Section name: Cellbody[60]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.297848922182621
#   Diameter (um): 6.499999999999999
# Section name: Cellbody[61]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.685488975874541
#   Diameter (um): 7.0
# Section name: Cellbody[62]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.6925112288488815
#   Diameter (um): 6.5
# Section name: Cellbody[63]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.655468841050982
#   Diameter (um): 5.999999999999999
# Section name: Cellbody[64]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.858539622799229
#   Diameter (um): 6.0
# Section name: Cellbody[65]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 0.8329404072700696
#   Diameter (um): 5.500000000000001
# Section name: Cellbody[66]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.3201542302431957
#   Diameter (um): 5.000000000000001
# Section name: Cellbody[67]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.1516891399840388
#   Diameter (um): 4.499999999999999
# Section name: Cellbody[68]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.310603889946624
#   Diameter (um): 4.0
# Section name: FieldD[0]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.578990789803949
#   Diameter (um): 9.800000190734863
# Section name: FieldD[1]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 12.921185449133574
#   Diameter (um): 5.0
# Section name: FieldD[2]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.1865544497977023
#   Diameter (um): 4.0
# Section name: FieldD[3]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 6.380171883423806
#   Diameter (um): 4.0
# Section name: FieldD[4]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.6345979619178426
#   Diameter (um): 3.0
# Section name: FieldD[5]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.871247151633432
#   Diameter (um): 2.0
# Section name: FieldD[6]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 0.7713604531776797
#   Diameter (um): 2.0
# Section name: FieldD[7]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.7195966932760762
#   Diameter (um): 2.0
# Section name: FieldD[8]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 13.085627334036147
#   Diameter (um): 4.0
# Section name: FieldD[9]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.603980105057797
#   Diameter (um): 6.0
# Section name: FieldD[10]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.4190065853214766
#   Diameter (um): 7.5
# Section name: FieldD[11]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 6.801833881618939
#   Diameter (um): 9.0
# Section name: FieldD[12]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.644873094659951
#   Diameter (um): 9.5
# Section name: FieldD[13]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.4843965684285743
#   Diameter (um): 10.0
# Section name: FieldD[14]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.143167418207829
#   Diameter (um): 10.0
# Section name: FieldD[15]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.6751422195682455
#   Diameter (um): 10.0
# Section name: FieldD[16]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.761685161608892
#   Diameter (um): 8.0
# Section name: FieldD[17]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.831317065274555
#   Diameter (um): 5.0
# Section name: FieldD[18]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.3356588730826373
#   Diameter (um): 7.0
# Section name: FieldD[19]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.364830667167333
#   Diameter (um): 8.0
# Section name: FieldD[20]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.6809529956349145
#   Diameter (um): 6.0
# Section name: FieldD[21]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.8247145682586563
#   Diameter (um): 6.0
# Section name: FieldD[22]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 0.8793822600870987
#   Diameter (um): 6.0
# Section name: FieldD[23]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.163820031266676
#   Diameter (um): 6.000000000000001
# Section name: FieldD[24]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.4442300206991465
#   Diameter (um): 5.999999999999999
# Section name: FieldD[25]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.3688041646614275
#   Diameter (um): 5.0
# Section name: FieldD[26]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.420166570002849
#   Diameter (um): 4.0
# Section name: FieldD[27]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.21742901485481
#   Diameter (um): 4.0
# Section name: FieldD[28]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.9339427021424067
#   Diameter (um): 3.9999999999999996
# Section name: FieldD[29]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.695459367514779
#   Diameter (um): 3.664999961853028
# Section name: FieldD[30]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 6.986557405125875
#   Diameter (um): 3.664999961853028
# Section name: FieldD[31]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.42835327105456
#   Diameter (um): 3.0
# Section name: FieldD[32]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.555262343188064
#   Diameter (um): 2.0
# Section name: FieldD[33]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 0.6325443878696435
#   Diameter (um): 2.0
# Section name: FieldD[34]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.896056989856236
#   Diameter (um): 2.0
# Section name: FieldD[35]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.5322052029183977
#   Diameter (um): 3.0
# Section name: FieldD[36]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.494080936970138
#   Diameter (um): 1.9999999999999998
# Section name: FieldD[37]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.4175319015949677
#   Diameter (um): 2.9999999999999996
# Section name: FieldD[38]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.382473092937427
#   Diameter (um): 3.0
# Section name: FieldD[39]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.1141400949333264
#   Diameter (um): 4.0
# Section name: FieldD[40]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.607921080543363
#   Diameter (um): 4.0
# Section name: FieldD[41]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.058873676453609
#   Diameter (um): 3.0
# Section name: FieldD[42]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.4876049998910013
#   Diameter (um): 2.0
# Section name: FieldD[43]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.224724691438996
#   Diameter (um): 6.0
# Section name: FieldD[44]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.741892117213974
#   Diameter (um): 7.0
# Section name: FieldD[45]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.04974926891542
#   Diameter (um): 6.0
# Section name: FieldD[46]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.2005094487755845
#   Diameter (um): 6.0
# Section name: FieldD[47]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.947595108585886
#   Diameter (um): 6.0
# Section name: FieldD[48]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.0587101990067733
#   Diameter (um): 6.000000000000001
# Section name: FieldD[49]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.6510068577460104
#   Diameter (um): 5.0
# Section name: FieldD[50]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.7179795397593782
#   Diameter (um): 4.0
# Section name: FieldD[51]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.7466084810148854
#   Diameter (um): 4.0
# Section name: FieldD[52]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.8561625579491332
#   Diameter (um): 4.0
# Section name: FieldD[53]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.7420014796394763
#   Diameter (um): 4.0
# Section name: FieldD[54]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.171370427959326
#   Diameter (um): 4.0
# Section name: FieldD[55]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.7901068824876765
#   Diameter (um): 4.0
# Section name: FieldD[56]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.156516409663647
#   Diameter (um): 4.0
# Section name: FieldD[57]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.4387661871927815
#   Diameter (um): 4.0
# Section name: FieldD[58]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.023292180114147
#   Diameter (um): 5.999999999999999
# Section name: FieldD[59]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.437214040992061
#   Diameter (um): 4.0
# Section name: FieldD[60]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.536014786268331
#   Diameter (um): 2.0
# Section name: FieldD[61]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.203639639450431
#   Diameter (um): 2.0
# Section name: FieldD[62]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.292061037812225
#   Diameter (um): 2.0
# Section name: FieldD[63]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.322431287519295
#   Diameter (um): 2.0
# Section name: FieldD[64]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 6.629055472166362
#   Diameter (um): 2.0
# Section name: FieldD[65]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 0.6269271078683087
#   Diameter (um): 2.0
# Section name: FieldD[66]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.1488053208548648
#   Diameter (um): 2.0
# Section name: FieldD[67]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 11.802827908737356
#   Diameter (um): 5.0
# Section name: FieldD[68]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.271373000811901
#   Diameter (um): 4.0
# Section name: FieldD[69]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.963521695660716
#   Diameter (um): 4.0
# Section name: FieldD[70]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.872670542132191
#   Diameter (um): 4.999999999999999
# Section name: FieldD[71]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 6.121915875953818
#   Diameter (um): 6.000000000000001
# Section name: FieldD[72]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.6673158586198253
#   Diameter (um): 5.000000000000001
# Section name: FieldD[73]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.0386035401527804
#   Diameter (um): 5.0
# Section name: FieldD[74]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.207799165870334
#   Diameter (um): 4.0
# Section name: FieldD[75]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.5682713876545358
#   Diameter (um): 2.0
# Section name: FieldD[76]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.605957509679455
#   Diameter (um): 2.0
# Section name: FieldD[77]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.9212894878603173
#   Diameter (um): 3.0
# Section name: FieldD[78]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 5.180382157960289
#   Diameter (um): 4.0
# Section name: FieldD[79]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 2.4680694325952706
#   Diameter (um): 4.0
# Section name: FieldD[80]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.470620186151182
#   Diameter (um): 4.0
# Section name: FieldD[81]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.3219750103167125
#   Diameter (um): 3.9999999999999996
# Section name: FieldD[82]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 4.978602708027411
#   Diameter (um): 2.0
# Section name: FieldD[83]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.392626509086731
#   Diameter (um): 2.0
# Section name: FieldD[84]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 3.366404451463599
#   Diameter (um): 2.0
# Section name: FieldD[85]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 1.6436572722856952
#   Diameter (um): 2.0
# Section name: FieldD[86]
#   Number of segments (nseg): 1
#   Number of nodes: 2
#   Length (um): 6.576348634703847
#   Diameter (um): 2.0

# %%
# Plot diameter of each section at different points wrt to distance from soma
fig = go.Figure()
for sec in LGMD1.allsec():
    # h.RangeVarPlot("rangevar" [, start_segment, stop_segment])
    rvp = h.RangeVarPlot ("diam", LGMD1.soma[0](0), sec(1))
    rvp.plot(fig)

fig.update_layout(
    title="Distance from soma for each segment vs. diameter change",
    xaxis_title="Distance from soma (um)",
    yaxis_title="Diameter (um)"
)

# %%
import re

segment_type_counts = {}
segment_type_nodes = {}

# Extract segment type names from all sections and count them
for sec in h.allsec():
    # Extract the segment type name (e.g., 'apic' from 'apic[1]')
    segment_type = re.split(r'\[', sec.name())[0]

    # Increment the count for this segment type
    segment_type_counts[segment_type] = segment_type_counts.get(segment_type, 0) + 1

    # Get the number of nodes (3D points) for this section
    num_nodes = int(sec.n3d())

    # Add the number of nodes to the total for this segment type
    segment_type_nodes[segment_type] = segment_type_nodes.get(segment_type, 0) + num_nodes

unique_segment_types = sorted(segment_type_counts.keys())

# Print the number of unique segment types and their segment and node counts
print(f"Number of unique segment types: {len(unique_segment_types)}")
for segment_type in unique_segment_types:
    num_segments = segment_type_counts[segment_type]
    total_nodes = segment_type_nodes[segment_type]
    print(f"  Segment Type: {segment_type}, Number of Segments: {num_segments}, Total Nodes: {total_nodes}")

# Total nodes after importing
total_nodes_in_tree = sum(segment_type_nodes.values())
print(f"Total number of nodes in this tree: {total_nodes_in_tree/2 +1}")

# soma = soma (1); axon = axon (2); dend = FieldA (3);
# Out:
# Number of unique segment types: 7
#   Segment Type: Axon, Number of Segments: 44, Total Nodes: 88
#   Segment Type: Cellbody, Number of Segments: 69, Total Nodes: 138
#   Segment Type: FieldA, Number of Segments: 1702, Total Nodes: 3404
#   Segment Type: FieldB, Number of Segments: 674, Total Nodes: 1348
#   Segment Type: FieldC, Number of Segments: 319, Total Nodes: 638
#   Segment Type: FieldD, Number of Segments: 87, Total Nodes: 174
#   Segment Type: soma, Number of Segments: 1, Total Nodes: 2
# Total number of nodes in this tree: 2897.0

# %%
# based on Peron, 2007
V_m = -65        # Resting membrane potential in mV
R_m = 5000       # Specific membrane resistivity in Ohm·cm²
C_m = 0.7          # Specific membrane capacitance in µF/cm² (NOT CORRECT, Should be <= 1)
#tau_m = 6.6      # Membrane time constant in ms
R_a = 57         # Axial resistance in Ohm·cm
G_pas = 1 / R_m  # Passive leaky conductance in S/cm²
# Input resistance is resistance at the point of current injection

# Insert passive properties into all sections and current injection
for sec in h.allsec():
    sec.insert('pas')        # Insert passive mechanism
    sec.Ra = R_a             # Axial resistivity (Ohm cm)
    sec.cm = C_m             # Membrane capacitance (uF/cm^2)
    sec.g_pas = G_pas        # Leak conductance (S/cm^2)
    sec.e_pas = V_m          # Leak reversal potential (mV)

def record_segment(inj_site, recor_site, current = -1, duration= 3250, stim_dur = 1500, delay = 250, init_vm=-65, delta_t=0.05):
    """
    Record and plot the membrane potential at a specific segment in the neuron.

    Parameters:
    - inj_site, recor_site (e.g., soma[0](0.5)).
    - duration: Total simulation time in ms
    - init_vm: Initial membrane potential
    """

    # Set simulation parameters
    h.tstop = duration  # Total duration in ms
    h.v_init = init_vm  # Initial V_m (mV)
    h.dt = delta_t      # Time step for simulation (ms)

    # Create current clamp at the specified segment
    stim = h.IClamp(inj_site)
    stim.delay = delay      # Start of stimulus (ms)
    stim.dur = stim_dur  # Duration of stimulus (ms)
    stim.amp = current   # Amplitude of stimulus (nA)

    # Record membrane potential and time
    v_vec = h.Vector()  # V_m vector
    t_vec = h.Vector()  # Time vector
    v_vec.record(recor_site._ref_v)
    t_vec.record(h._ref_t)

    # Initialize and run the simulation
    h.tstop = duration  # Total duration in ms
    h.finitialize(h.v_init)
    h.continuerun(h.tstop)

    return v_vec, t_vec

# %%
# Run current injection experiment with
current_values = [-1, -2,-4]  # nA

all_voltages = []
all_times = []
inj_site = LGMD1.FieldA[809](0.5) # base of field A
record_site = LGMD1.FieldA[809](0.5)

# Loop through each current value
for current in current_values:

    v_vec, t_vec = record_segment(inj_site, record_site, current=current)

    # Store the recorded voltage and time vectors
    all_voltages.append(np.array(v_vec))
    all_times.append(np.array(t_vec))

# Plot the results on same graph
plt.figure(figsize=(10, 6))
for i, current in enumerate(current_values):
    plt.plot(all_times[i], all_voltages[i], label=f"Current = {current} nA")

plt.xlabel("Time (ms)")
plt.ylabel("Membrane Potential (mV)")
plt.title("Membrane Potential for Different Current Injections")
plt.legend()
plt.show()

# %%
# Define the fitting function
np.set_printoptions(threshold=100)

def fit_passive_parameters(exp_vol, exp_t, inj_site, recor_site, stim_dur, current, init_vm = -65):
    """
    Fit Ra, cm, and g_pas to match the experimental voltage data.

    Parameters:
    - exp_vol: Array of experimental voltage data
    - exp_t: Array of experimental time point
    - inj_site, recor_site: Injection and recording sites (e.g., soma[0](0.5))
    - current: Current injection amplitude (nA)
    - init_vm: Initial membrane potential (mV)
    """
    delay_t =  np.round (abs (exp_t[0]) * 1000, decimals = 6) # convert to ms
    exp_t =  np.round ((exp_t + abs (exp_t[0])) * 1000, decimals = 6)  # shift to all positive
    current_end_time = delay_t + stim_dur  # End time of current injection
    t_fit_end = current_end_time
    t_fit_start = current_end_time - 1000

    exp_indices = np.where((exp_t >= t_fit_start) & (exp_t <= t_fit_end))[0]
    exp_v = exp_vol[exp_indices]
    exp_t_window = exp_t[exp_indices]

    # Check if the experimental data is sampled at constant intervals
    delta_t_exp = np.diff(exp_t_window)
    if not np.allclose(delta_t_exp, delta_t_exp[0]):
        print("Experimental data is not sampled at constant intervals. Cannot proceed without interpolation.")
        return

    delta_t_sim = np.round(delta_t_exp[0], decimals = 2) # Set simulation time step to match experimental sampling interval
    N_data = len(exp_t_window)  # Number of data points in fitting window
    print (N_data)

    mse_vec = []
    # Objective function to minimize
    def objective_function(params):
        Ra, cm, Rm = params
        print (f"Trying - Ra: {Ra}, cm: {cm}, g_pas: {1/Rm}")
        # Update model
        for sec in h.allsec():
            sec.insert('pas')
            sec.e_pas = init_vm  # fixed passive Voltage
            sec.Ra = Ra
            sec.cm = cm
            sec.g_pas = np.round (1/Rm, decimals = 5)

        # Simualtion to record voltage and interpolate to exp data
        sim_t = 1020
        duration = sim_t + delay_t + 10 # padding
        v_vec, t_vec = record_segment(inj_site, recor_site, current=current,
                                      duration=duration, stim_dur = sim_t,
                                      delay = delay_t, init_vm=init_vm, delta_t=delta_t_sim)
        v_vec = np.array(v_vec)
        t_vec = np.array(t_vec)

        # Only fit a 1000ms window during injection
        temp = int((sim_t + delay_t - 1000)/delta_t_sim)
        sim_v = v_vec[temp:N_data + temp]
        mse = np.mean((sim_v - exp_v) ** 2)
        mse_vec.append (mse)
        print (f"MSE: {mse}")
        return mse

    # Bounds for parameters
    bounds = [(58,62), (0.8, 1.2), (4000, 5000)]  # Ra, cm, R_M

    # Optimization function
    result = differential_evolution(objective_function, bounds, maxiter=10)

    Ra_opt, cm_opt, Rm_opt = result.x
    print("Optimized Ra:", Ra_opt)
    print("Optimized cm:", cm_opt)
    print("Optimized Rm:", Rm_opt)

    return result, exp_t, exp_vol, mse_vec

# %%
# Import exp data
import pandas as pd
data = pd.read_csv('/Users/samme/Library/CloudStorage/OneDrive-Emory/Lab/LGMD_project/LGMD_Data/Passive_CurrentClamp/experimental_data.csv', header=None)
experimental_t = data[0].values        # First column for time
experimental_voltage = data[1].values  # Second column for voltage

# Verify the arrays
print(f"Experimental Time and length ({len(experimental_t)}): {experimental_t}")
print(f"Experimental Voltage and length ({len(experimental_voltage)}): {experimental_voltage}")
inj_site = LGMD1.FieldA[809](0.5) # base of field A
record_site = LGMD1.FieldA[809](0.5)
# Out:
# Experimental Time and length (65237): [-0.24999 -0.24994 -0.24989 ...  2.9999   2.9999   3.     ]
# Experimental Voltage and length (65237): [-64.856 -64.849 -64.858 ... -65.035 -65.035 -65.034]

# %%
# Force the exp data into the shape of simulation
delay_duration = 0.25  # Delay period before t=0 in seconds
recording_duration = 1.5  # Recording period in seconds
post_recording_duration = 1.5

exp_vol_mod = []
delta_t = 0.05  # in ms
middle_segment_size = int(1.5 / (delta_t / 1000))  # Convert to number of elements: 1.5 sec / 0.00005 sec
exp_vol_mod = experimental_voltage[:5000]
middle_start_idx = np.where(experimental_t >= 0)[0][0]  # Find the index where t >= 0
exp_vol_mod = np.append(exp_vol_mod, experimental_voltage[middle_start_idx:middle_start_idx + middle_segment_size])
exp_vol_mod = np.append(exp_vol_mod, experimental_voltage[-30000:])


delay_steps = int(delay_duration / (delta_t / 1000))  # Convert to number of steps
recording_steps = int(recording_duration / (delta_t / 1000))
post_recording_steps = int(post_recording_duration / (delta_t / 1000))

delay_time = np.linspace(-delay_duration, 0, delay_steps, endpoint=False)  # Time before t=0
recording_time = np.linspace(0, recording_duration, recording_steps, endpoint=False)  # Time during recording
post_recording_time = np.linspace(recording_duration, recording_duration + post_recording_duration, post_recording_steps)

# Combine time segments to form exp_mod_t
exp_t_mod = np.concatenate((delay_time, recording_time, post_recording_time))

print (exp_vol_mod, len(exp_vol_mod))
print (exp_t_mod, len(exp_t_mod))
#plt.plot (exp_vol_mod)
plt.plot(exp_t_mod,exp_vol_mod, label="Experimental Data")
# Out:
# [-64.856 -64.849 -64.858 ... -65.035 -65.035 -65.034] 65000
# [-0.25    -0.24995 -0.2499  ...  2.9999   2.99995  3.     ] 65000

# %%
# Assuming inj_site and recor_site are defined, as in your previous code
Ra_opt, cm_opt, Rm_opt, exp_t,exp_vol  = fit_passive_parameters(
    exp_vol=exp_vol_mod,
    exp_t = exp_t_mod,
    inj_site=inj_site,
    recor_site=record_site,
    stim_dur = 1500,
    current=-2,   # Exp current value
    init_vm=-65,
)
# Out:
# 20001
# Trying - Ra: 58.290469464894585, cm: 1.1213325791612603, g_pas: 0.00020002129051415786
# MSE: nan
# Trying - Ra: 59.89121507958617, cm: 0.8775827236901714, g_pas: 0.00024104218109717115
# MSE: 0.4898337617337395
# Trying - Ra: 60.931588994729445, cm: 1.0036939483922012, g_pas: 0.00021398561122051577
# MSE: 0.21214338060177412
# Trying - Ra: 58.834688906900666, cm: 1.1803979456885916, g_pas: 0.00023869807172177573
# /var/folders/b_/nsxy2w2j4l50cg4c0jxc0qyr0000gn/T/ipykernel_52688/1350857669.py:60: RuntimeWarning:
#
# overflow encountered in square
#
# /Users/samme/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:181: RuntimeWarning:
#
# overflow encountered in reduce
# MSE: nan
# Trying - Ra: 60.36813820154874, cm: 0.8288469044176006, g_pas: 0.0002465547976455099
# MSE: 0.7983499463537953
# Trying - Ra: 60.82325501526508, cm: 1.1434999961785683, g_pas: 0.00022519258716797598
# MSE: 0.26634568093861993
# Trying - Ra: 60.64835009115952, cm: 0.8378712958805383, g_pas: 0.00024460039652100276
# MSE: 0.4867161996295526
# Trying - Ra: 60.25301333331563, cm: 1.1907933616746575, g_pas: 0.00024935820251754975
# MSE: 0.8010596893606865
# Trying - Ra: 58.980418202861294, cm: 1.0772138512690512, g_pas: 0.00023062540620668283
# MSE: 0.2697079199305869
# Trying - Ra: 58.78815408318534, cm: 1.1191049979081553, g_pas: 0.00023668864542154044
# MSE: nan
# Trying - Ra: 59.67298246216946, cm: 1.0245221562338498, g_pas: 0.0002320483228598067
# MSE: 0.2681354786705221
# Trying - Ra: 59.285198065326306, cm: 0.9707821537718511, g_pas: 0.00020347917281359333
# MSE: 0.4598373716557439
# Trying - Ra: 61.00674222442076, cm: 0.9099304409845637, g_pas: 0.00020173766167402385
# MSE: nan
# Trying - Ra: 59.502998202279045, cm: 1.106293866959386, g_pas: 0.00023946289710524888
# MSE: 0.4934025870679616
# Trying - Ra: 58.49062656154766, cm: 0.8174062672670543, g_pas: 0.00022855591650664323
# MSE: nan
# Trying - Ra: 61.624008137256254, cm: 1.1964218387022767, g_pas: 0.00024771761974023976
# MSE: nan
# Trying - Ra: 60.72832540756603, cm: 0.9453572859748554, g_pas: 0.00022785955098216212
# MSE: 0.2674718083593144
# Trying - Ra: 58.657269583613974, cm: 1.0968264138363346, g_pas: 0.00022485373243681734
# MSE: nan
# Trying - Ra: 59.993463440521445, cm: 0.9913239942496513, g_pas: 0.00024358853520342017
# MSE: 0.489943745676652
# Trying - Ra: 60.40129852204972, cm: 0.9630130420588409, g_pas: 0.00021270505813902977
# MSE: 0.21106363777059725
# Trying - Ra: 61.472478132716134, cm: 0.9282396847702639, g_pas: 0.0002174011627327503
# MSE: nan
# Trying - Ra: 59.16050615520388, cm: 0.8208374409867936, g_pas: 0.00020848393564799713
# MSE: 0.21126685549102586
# Trying - Ra: 60.1339210060922, cm: 0.8478908303130729, g_pas: 0.00020591461629573788
# MSE: 0.21068458963806236
# Trying - Ra: 61.0586537902475, cm: 0.8989153279782235, g_pas: 0.00023136436656052013
# MSE: 0.2646090194424377
# Trying - Ra: 58.037795035821794, cm: 1.0426603866335957, g_pas: 0.00022029305219674436
# MSE: nan
# Trying - Ra: 61.75339608055234, cm: 1.0515104889137759, g_pas: 0.00022285749100630796
# MSE: nan
# Trying - Ra: 61.11491886595373, cm: 1.1632565075574064, g_pas: 0.0002049274861381019
# MSE: 0.467148901068701
# Trying - Ra: 58.13192666084013, cm: 0.980361827869385, g_pas: 0.00022640844289942882
# MSE: nan
# Trying - Ra: 58.36832016158864, cm: 1.1361626307620583, g_pas: 0.00024314901323746715
# MSE: 0.5021712849304626
# Trying - Ra: 60.13040964917381, cm: 0.8834279148228686, g_pas: 0.0002380487316199232
# MSE: 0.488987281973138
# Trying - Ra: 59.07727433083603, cm: 1.0219284679156375, g_pas: 0.00021906838491855138
# MSE: 0.16678617382860778
# Trying - Ra: 59.40433249259458, cm: 0.9337416929965112, g_pas: 0.0002147459976851185
# MSE: 0.20943252844436
# Trying - Ra: 61.91430713335243, cm: 1.0706256420989524, g_pas: 0.0002354816214986051
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/b_/nsxy2w2j4l50cg4c0jxc0qyr0000gn/T/ipykernel_52688/399271052.py in <module>
#       1 # Assuming inj_site and recor_site are defined, as in your previous code
# ----> 2 Ra_opt, cm_opt, Rm_opt, exp_t,exp_vol  = fit_passive_parameters(
#       3     exp_vol=exp_vol_mod,
#       4     exp_t = exp_t_mod,
#       5     inj_site=inj_site,
#
# /var/folders/b_/nsxy2w2j4l50cg4c0jxc0qyr0000gn/T/ipykernel_52688/1350857669.py in fit_passive_parameters(exp_vol, exp_t, inj_site, recor_site, stim_dur, current, init_vm)
#      67
#      68     # Optimization function
# ---> 69     result = differential_evolution(objective_function, bounds, maxiter=10)
#      70
#      71     Ra_opt, cm_opt, Rm_opt = result.x
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentialevolution.py in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, seed, callback, disp, polish, init, atol, updating, workers, constraints, x0, integrality, vectorized)
#     395                                      integrality=integrality,
#     396                                      vectorized=vectorized) as solver:
# --> 397         ret = solver.solve()
#     398
#     399     return ret
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentialevolution.py in solve(self)
#     987             # only work out population energies for feasible solutions
#     988             self.population_energies[self.feasible] = (
# --> 989                 self._calculate_population_energies(
#     990                     self.population[self.feasible]))
#     991
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentialevolution.py in _calculate_population_energies(self, population)
#    1120         parameters_pop = self._scale_parameters(population)
#    1121         try:
# -> 1122             calc_energies = list(
#    1123                 self._mapwrapper(self.func, parameters_pop[0:S])
#    1124             )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/_lib/_util.py in __call__(self, x)
#     370
#     371     def __call__(self, x):
# --> 372         return self.f(x, *self.args)
#     373
#     374
#
# /var/folders/b_/nsxy2w2j4l50cg4c0jxc0qyr0000gn/T/ipykernel_52688/1350857669.py in objective_function(params)
#      49         sim_t = 1020
#      50         duration = sim_t + delay_t + 10 # padding
# ---> 51         v_vec, t_vec = record_segment(inj_site, recor_site, current=current,
#      52                                       duration=duration, stim_dur = sim_t,
#      53                                       delay = delay_t, init_vm=init_vm, delta_t=delta_t_sim)
#
# /var/folders/b_/nsxy2w2j4l50cg4c0jxc0qyr0000gn/T/ipykernel_52688/3765428462.py in record_segment(inj_site, recor_site, current, duration, stim_dur, delay, init_vm, delta_t)
#      46     h.tstop = duration  # Total duration in ms
#      47     h.finitialize(h.v_init)
# ---> 48     h.continuerun(h.tstop)
#      49
#      50     return v_vec, t_vec
#
# KeyboardInterrupt:

# %%
# Optimized parameters 
#Ra: 59.186074013451986, cm: 0.9871647241311633, g_pas: 0.00021581991562916785
Ra_opt = 59.186
cm_opt =0.987
g_pas = 0.0002158


delay_t =  np.round (abs (exp_t_mod[0]) * 1000, decimals = 6) # convert to ms
exp_t =  np.round ((exp_t_mod + abs (exp_t_mod[0])) * 1000, decimals = 6)
for sec in h.allsec():
  sec.insert('pas')
  sec.e_pas = -65  # Fixed passive Voltage
  sec.Ra = Ra_opt
  sec.cm = cm_opt
  sec.g_pas = g_pas

h.v_init = -65  # Initial V_m (mV)
h.dt = 0.05     # Time step for simulation (ms)

    # Create current clamp at the specified segment
stim = h.IClamp(LGMD1.FieldA[809](0.5))
stim.delay = 250      # Start of stimulus (ms)
stim.dur = 1500  # Duration of stimulus (ms)
stim.amp = -2   # Amplitude of stimulus (nA)

    # Record membrane potential and time
v_vec = h.Vector()  # V_m vector
t_vec = h.Vector()  # Time vector
recor_site = LGMD1.FieldA[809](0.5)
v_vec.record(recor_site._ref_v)
t_vec.record(h._ref_t)

    # Initialize and run the simulation
h.tstop = 3500  # Total duration in ms
h.finitialize(h.v_init)
h.continuerun(h.tstop)
v_vec = np.array (v_vec)[1:len(exp_t) + 1]
t_vec = np.array (t_vec)[1:len(exp_t) + 1]

    # Plot the fitted curve against experimental data
plt.figure(figsize=(10, 6))
plt.plot(exp_t , exp_vol_mod, label="Experimental Data")
plt.plot(t_vec, v_vec, label="Fitted Model", linestyle="--")
plt.xlabel("Time (ms)")
plt.ylabel("Membrane Potential (mV)")
plt.title("Fitting Model to Experimental Data")
plt.legend()
plt.show()
print (f"MSE: {np.mean((v_vec[5001:35000] - exp_vol_mod[5001:35000]) ** 2)}") # MSE for the injection period
print (f"Ra: {Ra_opt}, cm: {cm_opt}, g_pas: {g_pas}")
# Out:
# MSE: 2.954473259299243
# Ra: 59.186, cm: 0.987, g_pas: 0.0002158

# %%
Ra_opt = 58.93569860267176
cm_opt = 0.9056348761721569
g_pas = 0.00021828504860877366


delay_t =  np.round (abs (exp_t_mod[0]) * 1000, decimals = 6) # convert to ms
exp_t =  np.round ((exp_t_mod + abs (exp_t_mod[0])) * 1000, decimals = 6)
for sec in h.allsec():
  sec.insert('pas')
  sec.e_pas = -65  # Fixed passive Voltage
  sec.Ra = Ra_opt
  sec.cm = cm_opt
  sec.g_pas = g_pas

h.v_init = -65  # Initial V_m (mV)
h.dt = 0.05     # Time step for simulation (ms)

    # Create current clamp at the specified segment
stim = h.IClamp(LGMD1.FieldA[809](0.5))
stim.delay = 250      # Start of stimulus (ms)
stim.dur = 1500  # Duration of stimulus (ms)
stim.amp = -2   # Amplitude of stimulus (nA)

    # Record membrane potential and time
v_vec = h.Vector()  # V_m vector
t_vec = h.Vector()  # Time vector
recor_site = LGMD1.FieldA[809](0.5)
v_vec.record(recor_site._ref_v)
t_vec.record(h._ref_t)

    # Initialize and run the simulation
h.tstop = 3500  # Total duration in ms
h.finitialize(h.v_init)
h.continuerun(h.tstop)
v_vec = np.array (v_vec)[1:len(exp_t) + 1]
t_vec = np.array (t_vec)[1:len(exp_t) + 1]

    # Plot the fitted curve against experimental data
plt.figure(figsize=(10, 6))
plt.plot(exp_t , exp_vol_mod, label="Experimental Data")
plt.plot(t_vec, v_vec, label="Fitted Model", linestyle="--")
plt.xlabel("Time (ms)")
plt.ylabel("Membrane Potential (mV)")
plt.title("Fitting Model to Experimental Data")
plt.legend()
plt.show()
print (f"MSE: {np.mean((v_vec[5001:35000] - exp_vol_mod[5001:35000]) ** 2)}") # MSE for the injection period
print (f"Ra: {Ra_opt}, cm: {cm_opt}, g_pas: {g_pas}")
# Out:
# MSE: 12.851096357166979
# Ra: 58.93569860267176, cm: 0.9056348761721569, g_pas: 0.00021828504860877366
